# %%
from google.colab import drive
# drive.mount('/content/gdrive')
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import os
import glob
import pandas as pd
import pathlib
from itertools import combinations 
from collections import defaultdict

# %%
#Node structure for graph
class Node:

    def __init__(self,src,dest,wt):
        self.src = src
        self.dest = dest
        self.wt = wt


#Class to represent an un-directed graph using adjacency list representation 
class Graph: 
   
    def __init__(self,vertices): 
        self.V = vertices #No. of vertices 
        self.V_org = vertices 
        self.graph = defaultdict(list) # default dictionary to store graph 
        
        
    # function to add an edge to graph 
    def addEdge(self,u,v,w): 
        self.graph[u].append(Node(u,v,w))
        self.graph[v].append(Node(v,u,w))

        
    #function to print graph
    def printGraph(self):
        s = ""
        for i in self.graph:
            s = s + str(i) + " is connected to "
            print(str(i) + " is connected to ")
            for node in self.graph[i]:
                s = s + str(node.dest) + "(Weight = " + str(node.wt) + ")" + " "
                print(str(node.dest) + "(Weight = " + str(node.wt) + ")" + " ")
            s = s + "\n"
            print("\n")
        return s




class DataHandler:
    def __init__(self, path):
        self.type = pathlib.Path(path).suffix
        self.dataset_location = path
        
#         Use the pandas dataframe to get columns 
        if self.type == '.csv':
#             self.df = pd.read_csv(location, nrows=100)
            self.df = pd.read_csv(path)
            self.df = self.df[self.df['Domain'] == "CS "]
        elif self.type == '.xlsx':
            self.df = pd.read_excel(path)
            self.df = self.df[self.df['Domain'] == "CS "]

    def get_dataframe(self):
        return self.df

            
class keywordNodeNetGen:
    
    def __init__(self, path):
        self.path = path
        self.subsetSize = 2
        self.keysPair = []
        self.keywordsList = []
        self.dictKeywords = {}
        self.dictKeyVsPid = {}
        self.idList = []
        self.colName = []
    #     self.wbObj = openpyxl.load_workbook(self.path)
    #     self.sheetObj = self.wbObj.active    

    # #function to extract list of column headers from .xlsx
    # def extractListCol(self):
    #     maxCol = self.sheetObj.max_column    
    #     # Loop will print all columns name 
    #     for i in range(1, maxCol + 1): 
    #         cellObj = self.sheetObj.cell(row = 1, column = i) 
    #         self.colName.append(cellObj.value) 
    

    # #function to extract column index from its header
    # def extractColNumber(self, strIn):
    #     self.extractListCol()
    #     for x in self.colName:
    #         if x == strIn:
    #             colIndex = self.colName.index(x)+1
    #     return colIndex



    #function to extract list of keywords in all the research papers
    def extractDictOfKeywords(self):
        dh = DataHandler(self.path)
        df = dh.get_dataframe()
        # maxRow = 1000
        # keyIndex = self.extractColNumber('keywords')
        rowIndices = df.index.tolist()
        i=0
        # for rowIndex in df.index.tolist()
        for keyList in df['keywords']:
            if(i<1000): 
                self.dictKeywords[rowIndices[i]] = [keyword.strip() for keyword in re.split(";", keyList) if keyword]
                i=i+1

        return self.dictKeywords


    #function to create list of keywords in all papers
    def generateKeywordsList(self):
        self.dictKeywords = self.extractDictOfKeywords()
        # print(len(self.dictKeywords))
        self.keywordsList = list(set().union(*self.dictKeywords.values()))
        return self.keywordsList
    
    
    #function to find combinations of any 2 keywords
    def rSubset(self): 
        self.keywordsList = self.generateKeywordsList()
        self.keysPair = list(combinations(self.keywordsList, self.subsetSize)) 
        return self.keysPair
    
    
    #function to extract weight
    def pathWeight(self, x, y, dictKeywords, idList):
        edgeWeight = 0
        for idNo in idList:
            if(x in dictKeywords[idNo] and y in dictKeywords[idNo]):
                edgeWeight = edgeWeight + 1
        return edgeWeight
    
    
    #function to generate dictionary having keywords as keys and list of paper ids as value list 
    def generateDictKeyVsPid(self):
        self.keywordsList = self.generateKeywordsList()
        self.idList = self.dictKeywords.keys()
        self.dictKeyVsPid = {key:[pid for pid in self.idList if key in self.dictKeywords[pid]] for key in self.keywordsList}
        return self.dictKeyVsPid

# %%
# Driver Function 
if __name__ == "__main__": 
    path = "drive/My Drive/Colab Notebooks/Data.xlsx"
    netGen = keywordNodeNetGen(path)
    dictKeyVsPid = netGen.generateDictKeyVsPid()
    dictKeywords = netGen.extractDictOfKeywords()
    idList = dictKeywords.keys()
    nodesCount = len(netGen.generateKeywordsList())
    print(nodesCount)
    keyPairList = netGen.rSubset()
    g = Graph(nodesCount) 
    for i in keyPairList:
        edgeWeight = netGen.pathWeight(i[0],i[1],dictKeywords,idList)
        if edgeWeight>1:
            g.addEdge(i[0], i[1], edgeWeight)
        
        
    g.printGraph()
# Out:
# 4381
# DNA methylation is connected to
# gene expression(Weight = 2)
#
#
# gene expression is connected to
# DNA methylation(Weight = 2)
#
#
# security is connected to
# cloud computing(Weight = 4)
# privacy(Weight = 2)
#
#
# cloud computing is connected to
# security(Weight = 4)
# privacy(Weight = 2)
# virtualization(Weight = 2)
#
#
# privacy is connected to
# security(Weight = 2)
# cloud computing(Weight = 2)
#
#
# Resting-state fMRI is connected to
# Alzheimer's disease (AD)(Weight = 2)
# Mild cognitive impairment (MCI)(Weight = 2)
# Machine learning approach(Weight = 2)
#
#
# Alzheimer's disease (AD) is connected to
# Resting-state fMRI(Weight = 2)
# Mild cognitive impairment (MCI)(Weight = 2)
# Machine learning approach(Weight = 2)
#
#
# Mild cognitive impairment (MCI) is connected to
# Resting-state fMRI(Weight = 2)
# Alzheimer's disease (AD)(Weight = 2)
# Machine learning approach(Weight = 2)
#
#
# Machine learning approach is connected to
# Resting-state fMRI(Weight = 2)
# Alzheimer's disease (AD)(Weight = 2)
# Mild cognitive impairment (MCI)(Weight = 2)
#
#
# Data mining is connected to
# Classification(Weight = 2)
# Machine learning(Weight = 3)
#
#
# Classification is connected to
# Data mining(Weight = 2)
# Machine learning(Weight = 2)
# Feature selection(Weight = 6)
#
#
# Machine learning is connected to
# Data mining(Weight = 3)
# Classification(Weight = 2)
# Feature selection(Weight = 2)
# Support vector machine(Weight = 2)
# Cell segmentation(Weight = 2)
# Deep learning(Weight = 2)
# Artificial intelligence(Weight = 2)
# Image analysis(Weight = 2)
#
#
# Clustering is connected to
# Data Mining(Weight = 2)
#
#
# Data Mining is connected to
# Clustering(Weight = 2)
#
#
# Decryption is connected to
# Encryption(Weight = 2)
#
#
# Encryption is connected to
# Decryption(Weight = 2)
#
#
# domain decomposition is connected to
# finite element method (FEM)(Weight = 2)
# parallel computing(Weight = 2)
#
#
# finite element method (FEM) is connected to
# domain decomposition(Weight = 2)
#
#
# parallel computing is connected to
# domain decomposition(Weight = 2)
#
#
# Ultrasound is connected to
# Osteoporosis(Weight = 2)
# Biomedical image processing(Weight = 2)
# Biomedical signal processing(Weight = 2)
# Biomedical measurements(Weight = 2)
#
#
# Osteoporosis is connected to
# Ultrasound(Weight = 2)
# Biomedical image processing(Weight = 2)
# Biomedical signal processing(Weight = 2)
# Biomedical measurements(Weight = 2)
#
#
# Biomedical image processing is connected to
# Ultrasound(Weight = 2)
# Osteoporosis(Weight = 2)
# Biomedical signal processing(Weight = 2)
# Biomedical measurements(Weight = 2)
#
#
# Biomedical signal processing is connected to
# Ultrasound(Weight = 2)
# Osteoporosis(Weight = 2)
# Biomedical image processing(Weight = 2)
# Biomedical measurements(Weight = 2)
#
#
# Biomedical measurements is connected to
# Ultrasound(Weight = 2)
# Osteoporosis(Weight = 2)
# Biomedical image processing(Weight = 2)
# Biomedical signal processing(Weight = 2)
#
#
# Security is connected to
# Hadoop(Weight = 2)
#
#
# Hadoop is connected to
# Security(Weight = 2)
# Big Data(Weight = 2)
# MapReduce(Weight = 2)
#
#
# computational thinking is connected to
# computer programming(Weight = 2)
#
#
# computer programming is connected to
# computational thinking(Weight = 2)
#
#
# image segmentation is connected to
# feature extraction(Weight = 2)
#
#
# feature extraction is connected to
# image segmentation(Weight = 2)
# medical image processing(Weight = 2)
#
#
# Optimization is connected to
# Cloud computing(Weight = 2)
#
#
# Cloud computing is connected to
# Optimization(Weight = 2)
# Big data(Weight = 3)
#
#
# Big Data is connected to
# Hadoop(Weight = 2)
#
#
# MapReduce is connected to
# Hadoop(Weight = 2)
#
#
# virtualization is connected to
# cloud computing(Weight = 2)
# resource sharing(Weight = 2)
#
#
# Chaos is connected to
# S-box(Weight = 2)
# Cryptography(Weight = 2)
# Logistic map(Weight = 2)
#
#
# S-box is connected to
# Chaos(Weight = 2)
#
#
# Cryptography is connected to
# Chaos(Weight = 2)
#
#
# Logistic map is connected to
# Chaos(Weight = 2)
#
#
# Big data is connected to
# Parallel computing(Weight = 2)
# NoSQL(Weight = 2)
# Cloud computing(Weight = 3)
#
#
# Parallel computing is connected to
# Big data(Weight = 2)
#
#
# NoSQL is connected to
# Big data(Weight = 2)
#
#
# Symbolic computation is connected to
# Boiti-Leon-Manna-Pempinelli equation(Weight = 2)
# Hirota's bilinear form(Weight = 2)
#
#
# Boiti-Leon-Manna-Pempinelli equation is connected to
# Symbolic computation(Weight = 2)
# Hirota's bilinear form(Weight = 2)
#
#
# Hirota's bilinear form is connected to
# Symbolic computation(Weight = 2)
# Boiti-Leon-Manna-Pempinelli equation(Weight = 2)
#
#
# mobile phone is connected to
# mHealth(Weight = 2)
#
#
# mHealth is connected to
# mobile phone(Weight = 2)
#
#
# simulation is connected to
# software(Weight = 2)
#
#
# software is connected to
# simulation(Weight = 2)
#
#
# 7 [Computer Graphics] is connected to
# 3(Weight = 2)
# I(Weight = 2)
# Categories and Subject Descriptors (according to ACM CCS)(Weight = 2)
#
#
# 3 is connected to
# 7 [Computer Graphics](Weight = 2)
# I(Weight = 3)
# Categories and Subject Descriptors (according to ACM CCS)(Weight = 3)
#
#
# I is connected to
# 7 [Computer Graphics](Weight = 2)
# 3(Weight = 3)
# Categories and Subject Descriptors (according to ACM CCS)(Weight = 3)
#
#
# Categories and Subject Descriptors (according to ACM CCS) is connected to
# 7 [Computer Graphics](Weight = 2)
# 3(Weight = 3)
# I(Weight = 3)
#
#
# Feature selection is connected to
# Classification(Weight = 6)
# Machine learning(Weight = 2)
#
#
# Convolutional neural network is connected to
# Deep learning(Weight = 2)
#
#
# Deep learning is connected to
# Convolutional neural network(Weight = 2)
# Machine learning(Weight = 2)
# Convolutional neural networks(Weight = 2)
#
#
# Fault detection is connected to
# Dimensionality reduction(Weight = 2)
# Process monitoring(Weight = 2)
#
#
# Dimensionality reduction is connected to
# Fault detection(Weight = 2)
# Process monitoring(Weight = 2)
#
#
# Process monitoring is connected to
# Fault detection(Weight = 2)
# Dimensionality reduction(Weight = 2)
#
#
# resource sharing is connected to
# virtualization(Weight = 2)
#
#
# Support vector machine is connected to
# Machine learning(Weight = 2)
#
#
# Cell segmentation is connected to
# Machine learning(Weight = 2)
#
#
# Artificial intelligence is connected to
# Machine learning(Weight = 2)
#
#
# Image analysis is connected to
# Machine learning(Weight = 2)
#
#
# big data is connected to
# mapreduce(Weight = 2)
#
#
# mapreduce is connected to
# big data(Weight = 2)
#
#
# Convolutional neural networks is connected to
# Deep learning(Weight = 2)
#
#
# medical image processing is connected to
# feature extraction(Weight = 2)

# %%
#Node structure for graph
class Node:

    def __init__(self,src,dest,wt):
        self.src = src
        self.dest = dest
        self.wt = wt


#Class to represent an un-directed graph using adjacency list representation 
class Graph: 
   
    def __init__(self,vertices): 
        self.V = vertices #No. of vertices 
        self.V_org = vertices 
        self.graph = defaultdict(list) # default dictionary to store graph 
        
        
    # function to add an edge to graph 
    def addEdge(self,u,v,w): 
        self.graph[u].append(Node(u,v,w))
        self.graph[v].append(Node(v,u,w))

        
    #function to print graph
    def printGraph(self):
        s = ""
        for i in self.graph:
            s = s + str(i) + " is connected to "
            print(str(i) + " is connected to ")
            for node in self.graph[i]:
                s = s + str(node.dest) + "(Weight = " + str(node.wt) + ")" + " "
                print(str(node.dest) + "(Weight = " + str(node.wt) + ")" + " ")
            s = s + "\n"
            print("\n")
        return s




class DataHandler:
    def __init__(self, path):
        self.type = pathlib.Path(path).suffix
        self.dataset_location = path
        
#         Use the pandas dataframe to get columns 
        if self.type == '.csv':
#             self.df = pd.read_csv(location, nrows=100)
            self.df = pd.read_csv(path)
            self.df = self.df[self.df['Domain'] == "CS "]
        elif self.type == '.xlsx':
            self.df = pd.read_excel(path)
            self.df = self.df[self.df['Domain'] == "CS "]

    def get_dataframe(self):
        return self.df

            
class keywordNodeNetGen:
    
    def __init__(self, path):
        self.path = path
        self.subsetSize = 2
        self.keysPair = []
        self.keywordsList = []
        self.dictKeywords = {}
        self.dictKeyVsPid = {}
        self.idList = []
        self.colName = []
    #     self.wbObj = openpyxl.load_workbook(self.path)
    #     self.sheetObj = self.wbObj.active    

    # #function to extract list of column headers from .xlsx
    # def extractListCol(self):
    #     maxCol = self.sheetObj.max_column    
    #     # Loop will print all columns name 
    #     for i in range(1, maxCol + 1): 
    #         cellObj = self.sheetObj.cell(row = 1, column = i) 
    #         self.colName.append(cellObj.value) 
    

    # #function to extract column index from its header
    # def extractColNumber(self, strIn):
    #     self.extractListCol()
    #     for x in self.colName:
    #         if x == strIn:
    #             colIndex = self.colName.index(x)+1
    #     return colIndex



    #function to extract list of keywords in all the research papers
    def extractDictOfKeywords(self):
        dh = DataHandler(self.path)
        df = dh.get_dataframe()
        # maxRow = 1000
        # keyIndex = self.extractColNumber('keywords')
        rowIndices = df.index.tolist()
        i=0
        # for rowIndex in df.index.tolist()
        for keyList in df['Yake keywords']:
            if(i<1000): 
                self.dictKeywords[rowIndices[i]] = [keyword.strip() for keyword in re.split(";", keyList) if keyword]
                i=i+1

        return self.dictKeywords


    #function to create list of keywords in all papers
    def generateKeywordsList(self):
        self.dictKeywords = self.extractDictOfKeywords()
        # print(len(self.dictKeywords))
        self.keywordsList = list(set().union(*self.dictKeywords.values()))
        return self.keywordsList
    
    
    #function to find combinations of any 2 keywords
    def rSubset(self): 
        self.keywordsList = self.generateKeywordsList()
        self.keysPair = list(combinations(self.keywordsList, self.subsetSize)) 
        return self.keysPair
    
    
    #function to extract weight
    def pathWeight(self, x, y, dictKeywords, idList):
        edgeWeight = 0
        for idNo in idList:
            if(x in dictKeywords[idNo] and y in dictKeywords[idNo]):
                edgeWeight = edgeWeight + 1
        return edgeWeight
    
    
    #function to generate dictionary having keywords as keys and list of paper ids as value list 
    def generateDictKeyVsPid(self):
        self.keywordsList = self.generateKeywordsList()
        self.idList = self.dictKeywords.keys()
        self.dictKeyVsPid = {key:[pid for pid in self.idList if key in self.dictKeywords[pid]] for key in self.keywordsList}
        return self.dictKeyVsPid

# %%
# Driver Function 
if __name__ == "__main__": 
    path = "drive/My Drive/Colab Notebooks/Data.xlsx"
    netGenyake = keywordNodeNetGen(path)
    dictKeyVsPidyake = netGenyake.generateDictKeyVsPid()
    dictKeywordsyake = netGenyake.extractDictOfKeywords()
    idListyake = dictKeywordsyake.keys()
    nodesCountyake = len(netGenyake.generateKeywordsList())
    print(nodesCountyake)
    keyPairListyake = netGenyake.rSubset()
    gyake = Graph(nodesCountyake) 
    for i in keyPairListyake:
        edgeWeightyake = netGenyake.pathWeight(i[0],i[1],dictKeywordsyake,idListyake)
        if edgeWeightyake>1:
            gyake.addEdge(i[0], i[1], edgeWeightyake)
        
        
    gyake.printGraph()
# Out:
# 4222
# series data is connected to
# time series(Weight = 2)
#
#
# time series is connected to
# series data(Weight = 2)
#
#
# language processing is connected to
# natural language(Weight = 2)
#
#
# natural language is connected to
# language processing(Weight = 2)
#
#
# feature is connected to
# selection methods(Weight = 2)
# feature selection(Weight = 2)
# selection(Weight = 2)
#
#
# selection methods is connected to
# feature(Weight = 2)
# feature selection(Weight = 2)
# selection(Weight = 2)
#
#
# feature selection is connected to
# feature(Weight = 2)
# selection methods(Weight = 2)
# selection(Weight = 2)
#
#
# selection is connected to
# feature(Weight = 2)
# selection methods(Weight = 2)
# feature selection(Weight = 2)
#
#
# security is connected to
# network security(Weight = 2)
# network(Weight = 3)
#
#
# network security is connected to
# security(Weight = 2)
# intrusion detection(Weight = 2)
# network(Weight = 2)
#
#
# network is connected to
# security(Weight = 3)
# sdn(Weight = 2)
# algorithm(Weight = 2)
# network security(Weight = 2)
#
#
# software engineering is connected to
# software(Weight = 3)
# software development(Weight = 2)
#
#
# software is connected to
# software engineering(Weight = 3)
# software development(Weight = 3)
# model(Weight = 2)
#
#
# software development is connected to
# software engineering(Weight = 2)
# software(Weight = 3)
#
#
# sdn is connected to
# network(Weight = 2)
#
#
# equation is connected to
# bilinear equation(Weight = 2)
#
#
# bilinear equation is connected to
# equation(Weight = 2)
#
#
# fairfield university is connected to
# education academy(Weight = 2)
#
#
# education academy is connected to
# fairfield university(Weight = 2)
#
#
# ngs is connected to
# next-generation sequencing(Weight = 2)
#
#
# next-generation sequencing is connected to
# ngs(Weight = 2)
#
#
# distributed computing is connected to
# cloud(Weight = 2)
# cloud computing(Weight = 2)
#
#
# cloud is connected to
# distributed computing(Weight = 2)
# cloud computing(Weight = 10)
# information technology(Weight = 3)
# computing(Weight = 6)
#
#
# cloud computing is connected to
# distributed computing(Weight = 2)
# internet(Weight = 2)
# cloud(Weight = 10)
# information technology(Weight = 3)
# computing(Weight = 7)
#
#
# oct images is connected to
# oct(Weight = 2)
#
#
# oct is connected to
# oct images(Weight = 2)
#
#
# algorithm is connected to
# network(Weight = 2)
#
#
# computational thinking is connected to
# computer science(Weight = 2)
# computer programming(Weight = 2)
#
#
# computer science is connected to
# computational thinking(Weight = 2)
#
#
# computer programming is connected to
# computational thinking(Weight = 2)
#
#
# detection is connected to
# intrusion detection(Weight = 2)
#
#
# intrusion detection is connected to
# detection(Weight = 2)
# network security(Weight = 2)
#
#
# hepatocellular carcinoma is connected to
# hcc(Weight = 2)
#
#
# hcc is connected to
# hepatocellular carcinoma(Weight = 2)
#
#
# internet is connected to
# cloud computing(Weight = 2)
#
#
# data processing is connected to
# data(Weight = 2)
#
#
# data is connected to
# data processing(Weight = 2)
# information systems(Weight = 2)
# nosql(Weight = 2)
# big(Weight = 4)
# relational databases(Weight = 5)
# clustering(Weight = 3)
# big data(Weight = 11)
# data sets(Weight = 3)
# relational(Weight = 2)
#
#
# information systems is connected to
# data(Weight = 2)
#
#
# attack graph is connected to
# attack(Weight = 2)
#
#
# attack is connected to
# attack graph(Weight = 2)
#
#
# information technology is connected to
# cloud(Weight = 3)
# cloud computing(Weight = 3)
# computing(Weight = 2)
#
#
# computing is connected to
# cloud(Weight = 6)
# cloud computing(Weight = 7)
# information technology(Weight = 2)
#
#
# computer vision-based is connected to
# fire(Weight = 2)
#
#
# fire is connected to
# computer vision-based(Weight = 2)
#
#
# design is connected to
# algorithm design(Weight = 2)
#
#
# algorithm design is connected to
# design(Weight = 2)
#
#
# lung cancer is connected to
# cancer(Weight = 2)
# lung(Weight = 2)
#
#
# cancer is connected to
# lung cancer(Weight = 2)
# lung(Weight = 2)
#
#
# lung is connected to
# lung cancer(Weight = 2)
# cancer(Weight = 2)
#
#
# nosql is connected to
# data(Weight = 2)
#
#
# access control is connected to
# access(Weight = 2)
#
#
# access is connected to
# access control(Weight = 2)
#
#
# big is connected to
# data(Weight = 4)
# big data(Weight = 4)
#
#
# relational databases is connected to
# data(Weight = 5)
# big data(Weight = 2)
# relational(Weight = 2)
#
#
# clustering is connected to
# data(Weight = 3)
#
#
# big data is connected to
# data(Weight = 11)
# big(Weight = 4)
# relational databases(Weight = 2)
#
#
# data sets is connected to
# data(Weight = 3)
#
#
# relational is connected to
# data(Weight = 2)
# relational databases(Weight = 2)
#
#
# neural networks is connected to
# artificial neural(Weight = 2)
#
#
# artificial neural is connected to
# neural networks(Weight = 2)
#
#
# hirota bilinear is connected to
# bilinear method(Weight = 2)
#
#
# bilinear method is connected to
# hirota bilinear(Weight = 2)
#
#
# differential equations is connected to
# method(Weight = 2)
# partial differential(Weight = 2)
#
#
# method is connected to
# differential equations(Weight = 2)
# partial differential(Weight = 2)
#
#
# partial differential is connected to
# differential equations(Weight = 2)
# method(Weight = 2)
#
#
# reality system is connected to
# augmented reality(Weight = 2)
#
#
# augmented reality is connected to
# reality system(Weight = 2)
# augmented(Weight = 2)
#
#
# sensor network is connected to
# wireless sensor(Weight = 2)
#
#
# wireless sensor is connected to
# sensor network(Weight = 2)
# sensor networks(Weight = 2)
#
#
# sensor networks is connected to
# wireless sensor(Weight = 2)
#
#
# schrodinger equations is connected to
# nonlinear schrodinger(Weight = 2)
#
#
# nonlinear schrodinger is connected to
# schrodinger equations(Weight = 2)
# optical fiber(Weight = 2)
# schrodinger equation(Weight = 2)
#
#
# model is connected to
# software(Weight = 2)
#
#
# prime number is connected to
# generalized bilinear(Weight = 2)
#
#
# generalized bilinear is connected to
# prime number(Weight = 2)
#
#
# learning is connected to
# learning environments(Weight = 2)
#
#
# learning environments is connected to
# learning(Weight = 2)
#
#
# augmented is connected to
# augmented reality(Weight = 2)
#
#
# action recognition is connected to
# computer vision(Weight = 2)
#
#
# computer vision is connected to
# action recognition(Weight = 2)
# vision applications(Weight = 2)
#
#
# computer is connected to
# computer graphics(Weight = 2)
# graphics(Weight = 2)
#
#
# computer graphics is connected to
# computer(Weight = 2)
# graphics(Weight = 3)
#
#
# graphics is connected to
# computer(Weight = 2)
# computer graphics(Weight = 3)
#
#
# emission tomography is connected to
# positron emission(Weight = 2)
#
#
# positron emission is connected to
# emission tomography(Weight = 2)
#
#
# vision applications is connected to
# computer vision(Weight = 2)
#
#
# answering is connected to
# question answering(Weight = 2)
#
#
# question answering is connected to
# answering(Weight = 2)
#
#
# optical fiber is connected to
# nonlinear schrodinger(Weight = 2)
#
#
# data mining is connected to
# machine learning(Weight = 2)
#
#
# machine learning is connected to
# data mining(Weight = 2)
#
#
# schrodinger equation is connected to
# nonlinear schrodinger(Weight = 2)

# %%
#Node structure for graph
class Node:

    def __init__(self,src,dest,wt):
        self.src = src
        self.dest = dest
        self.wt = wt


#Class to represent an un-directed graph using adjacency list representation 
class Graph: 
   
    def __init__(self,vertices): 
        self.V = vertices #No. of vertices 
        self.V_org = vertices 
        self.graph = defaultdict(list) # default dictionary to store graph 
        
        
    # function to add an edge to graph 
    def addEdge(self,u,v,w): 
        self.graph[u].append(Node(u,v,w))
        self.graph[v].append(Node(v,u,w))

        
    #function to print graph
    def printGraph(self):
        s = ""
        for i in self.graph:
            s = s + str(i) + " is connected to "
            print(str(i) + " is connected to ")
            for node in self.graph[i]:
                s = s + str(node.dest) + "(Weight = " + str(node.wt) + ")" + " "
                print(str(node.dest) + "(Weight = " + str(node.wt) + ")" + " ")
            s = s + "\n"
            print("\n")
        return s




class DataHandler:
    def __init__(self, path):
        self.type = pathlib.Path(path).suffix
        self.dataset_location = path
        
#         Use the pandas dataframe to get columns 
        if self.type == '.csv':
#             self.df = pd.read_csv(location, nrows=100)
            self.df = pd.read_csv(path)
            self.df = self.df[self.df['Domain'] == "CS "]
        elif self.type == '.xlsx':
            self.df = pd.read_excel(path)
            self.df = self.df[self.df['Domain'] == "CS "]

    def get_dataframe(self):
        return self.df

            
class keywordNodeNetGen:
    
    def __init__(self, path):
        self.path = path
        self.subsetSize = 2
        self.keysPair = []
        self.keywordsList = []
        self.dictKeywords = {}
        self.dictKeyVsPid = {}
        self.idList = []
        self.colName = []
    #     self.wbObj = openpyxl.load_workbook(self.path)
    #     self.sheetObj = self.wbObj.active    

    # #function to extract list of column headers from .xlsx
    # def extractListCol(self):
    #     maxCol = self.sheetObj.max_column    
    #     # Loop will print all columns name 
    #     for i in range(1, maxCol + 1): 
    #         cellObj = self.sheetObj.cell(row = 1, column = i) 
    #         self.colName.append(cellObj.value) 
    

    # #function to extract column index from its header
    # def extractColNumber(self, strIn):
    #     self.extractListCol()
    #     for x in self.colName:
    #         if x == strIn:
    #             colIndex = self.colName.index(x)+1
    #     return colIndex



    #function to extract list of keywords in all the research papers
    def extractDictOfKeywords(self):
        dh = DataHandler(self.path)
        df = dh.get_dataframe()
        # maxRow = 1000
        # keyIndex = self.extractColNumber('keywords')
        rowIndices = df.index.tolist()
        i=0
        # for rowIndex in df.index.tolist()
        for keyList in df['Rake keywords']:
            if(i<1000): 
                self.dictKeywords[rowIndices[i]] = [keyword.strip() for keyword in re.split(";", keyList) if keyword]
                i=i+1

        return self.dictKeywords


    #function to create list of keywords in all papers
    def generateKeywordsList(self):
        self.dictKeywords = self.extractDictOfKeywords()
        # print(len(self.dictKeywords))
        self.keywordsList = list(set().union(*self.dictKeywords.values()))
        return self.keywordsList
    
    
    #function to find combinations of any 2 keywords
    def rSubset(self): 
        self.keywordsList = self.generateKeywordsList()
        self.keysPair = list(combinations(self.keywordsList, self.subsetSize)) 
        return self.keysPair
    
    
    #function to extract weight
    def pathWeight(self, x, y, dictKeywords, idList):
        edgeWeight = 0
        for idNo in idList:
            if(x in dictKeywords[idNo] and y in dictKeywords[idNo]):
                edgeWeight = edgeWeight + 1
        return edgeWeight
    
    
    #function to generate dictionary having keywords as keys and list of paper ids as value list 
    def generateDictKeyVsPid(self):
        self.keywordsList = self.generateKeywordsList()
        self.idList = self.dictKeywords.keys()
        self.dictKeyVsPid = {key:[pid for pid in self.idList if key in self.dictKeywords[pid]] for key in self.keywordsList}
        return self.dictKeyVsPid

# %%
# Driver Function 
if __name__ == "__main__": 
    path = "drive/My Drive/Colab Notebooks/Data.xlsx"
    netGen = keywordNodeNetGen(path)
    dictKeyVsPid = netGen.generateDictKeyVsPid()
    dictKeywords = netGen.extractDictOfKeywords()
    idList = dictKeywords.keys()
    nodesCount = len(netGen.generateKeywordsList())
    print(nodesCount)
    keyPairList = netGen.rSubset()
    g = Graph(nodesCount) 
    for i in keyPairList:
        edgeWeight = netGen.pathWeight(i[0],i[1],dictKeywords,idList)
        if edgeWeight>1:
            g.addEdge(i[0], i[1], edgeWeight)
        
        
    g.printGraph()
# Out:
# 4222
# series data is connected to
# time series(Weight = 2)
#
#
# time series is connected to
# series data(Weight = 2)
#
#
# language processing is connected to
# natural language(Weight = 2)
#
#
# natural language is connected to
# language processing(Weight = 2)
#
#
# feature is connected to
# selection methods(Weight = 2)
# feature selection(Weight = 2)
# selection(Weight = 2)
#
#
# selection methods is connected to
# feature(Weight = 2)
# feature selection(Weight = 2)
# selection(Weight = 2)
#
#
# feature selection is connected to
# feature(Weight = 2)
# selection methods(Weight = 2)
# selection(Weight = 2)
#
#
# selection is connected to
# feature(Weight = 2)
# selection methods(Weight = 2)
# feature selection(Weight = 2)
#
#
# security is connected to
# network security(Weight = 2)
# network(Weight = 3)
#
#
# network security is connected to
# security(Weight = 2)
# intrusion detection(Weight = 2)
# network(Weight = 2)
#
#
# network is connected to
# security(Weight = 3)
# sdn(Weight = 2)
# algorithm(Weight = 2)
# network security(Weight = 2)
#
#
# software engineering is connected to
# software(Weight = 3)
# software development(Weight = 2)
#
#
# software is connected to
# software engineering(Weight = 3)
# software development(Weight = 3)
# model(Weight = 2)
#
#
# software development is connected to
# software engineering(Weight = 2)
# software(Weight = 3)
#
#
# sdn is connected to
# network(Weight = 2)
#
#
# equation is connected to
# bilinear equation(Weight = 2)
#
#
# bilinear equation is connected to
# equation(Weight = 2)
#
#
# fairfield university is connected to
# education academy(Weight = 2)
#
#
# education academy is connected to
# fairfield university(Weight = 2)
#
#
# ngs is connected to
# next-generation sequencing(Weight = 2)
#
#
# next-generation sequencing is connected to
# ngs(Weight = 2)
#
#
# distributed computing is connected to
# cloud(Weight = 2)
# cloud computing(Weight = 2)
#
#
# cloud is connected to
# distributed computing(Weight = 2)
# cloud computing(Weight = 10)
# information technology(Weight = 3)
# computing(Weight = 6)
#
#
# cloud computing is connected to
# distributed computing(Weight = 2)
# internet(Weight = 2)
# cloud(Weight = 10)
# information technology(Weight = 3)
# computing(Weight = 7)
#
#
# oct images is connected to
# oct(Weight = 2)
#
#
# oct is connected to
# oct images(Weight = 2)
#
#
# algorithm is connected to
# network(Weight = 2)
#
#
# computational thinking is connected to
# computer science(Weight = 2)
# computer programming(Weight = 2)
#
#
# computer science is connected to
# computational thinking(Weight = 2)
#
#
# computer programming is connected to
# computational thinking(Weight = 2)
#
#
# detection is connected to
# intrusion detection(Weight = 2)
#
#
# intrusion detection is connected to
# detection(Weight = 2)
# network security(Weight = 2)
#
#
# hepatocellular carcinoma is connected to
# hcc(Weight = 2)
#
#
# hcc is connected to
# hepatocellular carcinoma(Weight = 2)
#
#
# internet is connected to
# cloud computing(Weight = 2)
#
#
# data processing is connected to
# data(Weight = 2)
#
#
# data is connected to
# data processing(Weight = 2)
# information systems(Weight = 2)
# nosql(Weight = 2)
# big(Weight = 4)
# relational databases(Weight = 5)
# clustering(Weight = 3)
# big data(Weight = 11)
# data sets(Weight = 3)
# relational(Weight = 2)
#
#
# information systems is connected to
# data(Weight = 2)
#
#
# attack graph is connected to
# attack(Weight = 2)
#
#
# attack is connected to
# attack graph(Weight = 2)
#
#
# information technology is connected to
# cloud(Weight = 3)
# cloud computing(Weight = 3)
# computing(Weight = 2)
#
#
# computing is connected to
# cloud(Weight = 6)
# cloud computing(Weight = 7)
# information technology(Weight = 2)
#
#
# computer vision-based is connected to
# fire(Weight = 2)
#
#
# fire is connected to
# computer vision-based(Weight = 2)
#
#
# design is connected to
# algorithm design(Weight = 2)
#
#
# algorithm design is connected to
# design(Weight = 2)
#
#
# lung cancer is connected to
# cancer(Weight = 2)
# lung(Weight = 2)
#
#
# cancer is connected to
# lung cancer(Weight = 2)
# lung(Weight = 2)
#
#
# lung is connected to
# lung cancer(Weight = 2)
# cancer(Weight = 2)
#
#
# nosql is connected to
# data(Weight = 2)
#
#
# access control is connected to
# access(Weight = 2)
#
#
# access is connected to
# access control(Weight = 2)
#
#
# big is connected to
# data(Weight = 4)
# big data(Weight = 4)
#
#
# relational databases is connected to
# data(Weight = 5)
# big data(Weight = 2)
# relational(Weight = 2)
#
#
# clustering is connected to
# data(Weight = 3)
#
#
# big data is connected to
# data(Weight = 11)
# big(Weight = 4)
# relational databases(Weight = 2)
#
#
# data sets is connected to
# data(Weight = 3)
#
#
# relational is connected to
# data(Weight = 2)
# relational databases(Weight = 2)
#
#
# neural networks is connected to
# artificial neural(Weight = 2)
#
#
# artificial neural is connected to
# neural networks(Weight = 2)
#
#
# hirota bilinear is connected to
# bilinear method(Weight = 2)
#
#
# bilinear method is connected to
# hirota bilinear(Weight = 2)
#
#
# differential equations is connected to
# method(Weight = 2)
# partial differential(Weight = 2)
#
#
# method is connected to
# differential equations(Weight = 2)
# partial differential(Weight = 2)
#
#
# partial differential is connected to
# differential equations(Weight = 2)
# method(Weight = 2)
#
#
# reality system is connected to
# augmented reality(Weight = 2)
#
#
# augmented reality is connected to
# reality system(Weight = 2)
# augmented(Weight = 2)
#
#
# sensor network is connected to
# wireless sensor(Weight = 2)
#
#
# wireless sensor is connected to
# sensor network(Weight = 2)
# sensor networks(Weight = 2)
#
#
# sensor networks is connected to
# wireless sensor(Weight = 2)
#
#
# schrodinger equations is connected to
# nonlinear schrodinger(Weight = 2)
#
#
# nonlinear schrodinger is connected to
# schrodinger equations(Weight = 2)
# optical fiber(Weight = 2)
# schrodinger equation(Weight = 2)
#
#
# model is connected to
# software(Weight = 2)
#
#
# prime number is connected to
# generalized bilinear(Weight = 2)
#
#
# generalized bilinear is connected to
# prime number(Weight = 2)
#
#
# learning is connected to
# learning environments(Weight = 2)
#
#
# learning environments is connected to
# learning(Weight = 2)
#
#
# augmented is connected to
# augmented reality(Weight = 2)
#
#
# action recognition is connected to
# computer vision(Weight = 2)
#
#
# computer vision is connected to
# action recognition(Weight = 2)
# vision applications(Weight = 2)
#
#
# computer is connected to
# computer graphics(Weight = 2)
# graphics(Weight = 2)
#
#
# computer graphics is connected to
# computer(Weight = 2)
# graphics(Weight = 3)
#
#
# graphics is connected to
# computer(Weight = 2)
# computer graphics(Weight = 3)
#
#
# emission tomography is connected to
# positron emission(Weight = 2)
#
#
# positron emission is connected to
# emission tomography(Weight = 2)
#
#
# vision applications is connected to
# computer vision(Weight = 2)
#
#
# answering is connected to
# question answering(Weight = 2)
#
#
# question answering is connected to
# answering(Weight = 2)
#
#
# optical fiber is connected to
# nonlinear schrodinger(Weight = 2)
#
#
# data mining is connected to
# machine learning(Weight = 2)
#
#
# machine learning is connected to
# data mining(Weight = 2)
#
#
# schrodinger equation is connected to
# nonlinear schrodinger(Weight = 2)
